# %%
from langchain_community.document_loaders import PyPDFLoader
pdfloader = PyPDFLoader('attention.pdf')
docs = pdfloader.load()

# %%
##Recursively splitting text characters 
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_docs = text_splitter.split_documents(docs)
final_docs

# %%
print(final_docs[0])
print(final_docs[1])

# %%
from langchain_community.document_loaders import TextLoader
docs = TextLoader("speech.txt").load()
speech=""
with open("speech.txt",'r') as f:
    speech = f.read()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap = 20)
text = text_splitter.create_documents([speech])
print(text[0])

# %%
print(type(text[0]))

# %%
##Another type of splitter is the CharacterTextSplitter to specify the character at which we specifically want to break the data into a chunk

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
html_string = """
<!DOCTYPE html>
<html>
<body>
    <div>
        <h1>Foo</h1>
        <p>Some intro text about Foo.</p>
        <div>
            <h2>Bar main section</h2>
            <p>Some intro text about Bar.</p>
            <h3>Bar subsection 1</h3>
            <p>Some text about the first subtopic of Bar.</p>
            <h3>Bar subsection 2</h3>
            <p>Some text about the second subtopic of Bar.</p>
        </div>
        <div>
            <h2>Baz</h2>
            <p>Some text about Baz</p>
        </div>
        <br>
        <p>Some concluding text about Foo</p>
    </div>
</body>
</html>
"""
headers_to_split_on = [
    ("h1","Header 1"),
    ("h2","Header 2"),("h3","Header 3")
    ]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
splits = html_splitter.split_text(html_string)
splits

# %%
import json
import requests
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()

# %%
from langchain_text_splitters import RecursiveJsonSplitter
json_splitter = RecursiveJsonSplitter(max_chunk_size=300)
json_chunks = json_splitter.split_json(json_data)
json_chunks

# %%
for chunk in json_chunks[:3]:
    print(chunk)

# %%
##convert to document
docs = json_splitter.create_documents(texts=[json_data])
for doc in docs[:3]:
    print(doc)

# %%
##to text
texts = json_splitter.split_text(json_data)
print(texts[0])
print(texts[1])
